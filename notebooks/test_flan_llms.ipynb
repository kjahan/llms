# %% [markdown]
# # Install and Import Package
#
# ### Language Models
# Python building blocks to explore large language models on any computer with 512MB of RAM
#
# run smaller size llms on a single machine with < 512MB ram
#
# https://github.com/jncraton/languagemodels
#
# https://huggingface.co/jncraton/flan-alpaca-base-ct2-int8

# %%
# %pip install languagemodels

import languagemodels as lm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Translation Example

# %%
lm.do("Translate to English: Hola, mundo!")
# Out:
# ...
# 'Hello, world!'

# %%
lm.do("What color is the sky?")
# Out:
# 'The color of the sky is blue.'

# %%
lm.do("What is mitosis?")
# Out:
# 'Mitosis is the process of cell division that results in two identical daughter cells.'

# %%
lm.do("how is mitosis different from meiosis")
# Out:
# 'Mitosis is a type of cell division that results in two identical daughter cells, while meiosis is a type of cell division that results in four genetically diverse daughter cells. Mitosis involves the separation of the chromosomes during prophase, while meiosis involves the separation of the chromosomes during metaphase.'

# %%
lm.complete("She hid in her room until")
# Out:
# ' she was ready to go.'

# %%
lm.do("Translate to Persian: Hola, mundo!")
# Out:
# ' ⁇   ⁇ !'

# %%
lm.do("Translate to French: Hola, mundo!")
# Out:
# 'Bonjour, mon ami!'

# %%
lm.do("Translate to Korean: Hola, mundo!")
# Out:
# ' ⁇ ,  ⁇ !'

# %%
lm.do("Translate to Japanese: Hola, mundo!")
# Out:
# ' ⁇ .'

# %%
lm.chat('''System: Respond as a helpful assistant.
User: What time is it?
Assistant:''')
# Out:
# "I'm sorry, but as an AI language model, I don't have access to real-time information. Please check your calendar or phone for the current time."

# %%
lm.chat('''System: Respond as a helpful assistant.
User: Who is US president?
Assistant:''')
# Out:
# 'George W. Bush.'

# %%
lm.get_wiki('Chemistry')
# Out:
# 'Chemistry is the scientific study of the properties and behavior of matter. It is a physical science under natural sciences that covers the elements that make up matter to the compounds made of atoms, molecules and ions: their composition, structure, properties, behavior and the changes they undergo during a reaction with other substances. Chemistry also addresses the nature of chemical bonds in chemical compounds.\nIn the scope of its subject, chemistry occupies an intermediate position between physics and biology. It is sometimes called the central science because it provides a foundation for understanding both basic and applied scientific disciplines at a fundamental level. For example, chemistry explains aspects of plant growth (botany), the formation of igneous rocks (geology), how atmospheric ozone is formed and how environmental pollutants are degraded (ecology), the properties of the soil on the moon (cosmochemistry), how medications work (pharmacology), and how to collect D
# ...

# %%
lm.get_weather(41.8, -87.6)
# Out:
# 'Mostly clear, with a low around 59. East southeast wind around 5 mph.'

# %%
lm.get_date()
# Out:
# 'Sunday, June 18, 2023 at 12:04AM'

# %%
lm.chat(f'''
...      System: Respond as a helpful assistant. It is {lm.get_date()}
...
...      User: What time is it?
...
...      Assistant:
...      ''')
# Out:
# 'It is Sunday, June 18, 2023 at 12:05AM.'

# %%
lm.store_doc("Mars is a planet")
lm.store_doc("The sun is hot")
lm.load_doc("What is Mars?")
# Out:
# ...
# 'Mars is a planet'

# %%
lm.store_doc(lm.get_wiki("Python"))
lm.store_doc(lm.get_wiki("C language"))
lm.store_doc(lm.get_wiki("Javascript"))
lm.store_doc(lm.get_wiki("Fortran"))
lm.get_doc_context("What does it mean for batteries to be included in a language?")
# Out:
# 'multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language\n\noften incorporating third-party libraries. All major web browsers have a dedicated JavaScript engine to execute the code on users\' devices. JavaScript is a high-level, often just-in-time compiled language that conforms to the ECMAScript standard. It has dynamic typing, prototype'

# %%
lm.do("If I have 7 apples then eat 5, how many apples do I have?")
# Out:
# 'You have 8 apples.'

# %%
lm.set_max_ram('4gb')
lm.do("If I have 7 apples then eat 5, how many apples do I have?")
# Out:
# ...
# 'I have 2 apples left.'
